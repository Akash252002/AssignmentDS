# %%
# Ans no1

import logging

logging.basicConfig(filename="12feb.log",level=logging.INFO,format='%(message)s %(asctime)s')
logging.info("the first ans is writting now")

'''In Python, an exception is an event, during the execution of a program, 
that disrupts the normal flow of the program's instructions.
 Exceptions are raised when a program encounters an error condition,
  such as division by zero or trying to access an index in a list that is out of range.

The difference between exceptions and syntax errors is that syntax errors are errors in the code itself, 
such as a syntax mistake, a typo, or incorrect indentation, that prevent the code from running. 
On the other hand, exceptions are generated by the code that is already syntactically correct,
 but the execution of the code encounters an error condition, such as an arithmetic operation with invalid operands.

Syntax errors are detected by the Python interpreter when the code is first parsed and will prevent the code from executing.
 On the other hand, exceptions are raised during the execution of the code and can be handled using try-except blocks,
  allowing the program to continue running even if an error has occurred.'''

# %%
# Ans no2

logging.info("the 2ns ans is writting now")

'''When an exception is not handled in Python, the program will raise the uncaught exception and terminate immediately. 
This means that any subsequent code that was supposed to run will not be executed, and the program will stop working.'''

#  example
logging.info("abut exception")
a=int(input("enter a"))
b=int(input("enter b"))
print(a/b)
# Out:
# enter a 23
# enter b 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [9], line 10
#       8 a=int(input("enter a"))
#       9 b=int(input("enter b"))
# ---> 10 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
# Ans no3

logging.info("the 3rd ans is writting now")

''' the try and except statements are used to handle exceptions.'''
# example

logging.info("abut the try and except in q3")

try:
    f=open("f.txt",'r')
except Exception as e:
    print("there is an exception in the code")
# Out:
# there is an exception in the code

# %%
# Ans no4

logging.info("the 4rth ans is writting now")

'''try and else are use to handle the exception wich are generated on the execution of the code '''
# example
logging.info("abut the try and except")
a=int(input("enter a")) #enter 34
b=int(input("enter b")) #enter 0
print(a/b) # 34/0 will generate an exception


''' finally is the exception handler whilch will execute in any situation 
'''
# example2
try :
   f=open("asdf.txt",'r')

finally:
    print("filnally will print in any situation")

'''The raise statement in Python is used to raise an exception. It allows to throw an error manually, 
which can be caught and handled by a try-except block. This can be useful in situations 
where you want to force an error to occur in your code to handle certain conditions.'''

# example3

logging.info("declaring the class for showing errors")

class valid (Exception):

    def __init__(self, message) :
        self.mess=message

logging.info("declaring the function for taking input as age") 

def validate(age):
    if age<0:
        raise valid("age cant be nagetive")  
    elif age>200:
        raise valid("age cant be grater than 200")         
    else:
        print("valid age")
        
logging.info("use the exception handelers")   
     
try:
    a=int(input("enter age"))
    validate(a)
except valid as v:
    print(v)
# Out:
# enter age 223
# age cant be grater than 200

# %%
# Ans no5

logging.info("the 5th ans is writting now")

'''Custom exceptions can be useful when you want to provide more meaningful error messages to the user,
 or to differentiate between different types of errors in your code. However,
  it's important to use custom exceptions judiciously and only when it's necessary, 
  as they can make your code harder to understand and debug.

  ustom exceptions in Python are user-defined exceptions that can be raised and caught in a try-except block 
  just like built-in exceptions. Custom exceptions allow you to add additional information to an exception
 and make it easier to understand the source and cause of the error in your code.

'''
# example
# example3
logging.info("declaring the class for showing errors")

class valid (Exception):

    def __init__(self, message) :
        self.mess=message

logging.info("declaring the function for taking input as age") 

def validate(age):
    if age<0:
        raise valid("age cant be nagetive")  
    elif age>200:
        raise valid("age cant be grater than 200")         
    else:
        print("valid age")
        
logging.info("use the exception handelers")     
   
try:
    a=int(input("enter age"))
    validate(a)
except valid as v:
    print(v)
# Out:
# enter age -654
# age cant be nagetive

# %%
# Ans no6

logging.info("the 6th ans is writting now")

logging.info("declaring the class for showing errors")

class valid (Exception):

    def __init__(self, message) :
        self.mess=message

logging.info("declaring the function for taking input as age") 

def validate(age):
    if age<0:
        raise valid("age cant be nagetive")  
    elif age>200:
        raise valid("age cant be grater than 200")         
    else:
        print("valid age")
        
logging.info("use the exception handelers")    
    
try:
    a=int(input("enter age"))
    validate(a)
except valid as v:
    print(v)
# Out:
# enter age 33
# valid age
